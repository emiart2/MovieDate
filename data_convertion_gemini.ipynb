# %%
from google import genai
import os

MODEL = "gemini-2.0-flash"

client = genai.Client(api_key="AIzaSyAt-uSUQDuqh6tqcvrDcJ-vWbjmDiGqMqw")

response = client.models.generate_content(
    model=MODEL,
    contents=["Hello, world!"]
)
print(response.text)
# Out:
# Hello there! How can I help you today?

# %%
import pandas as pd

data = pd.read_csv('data/netflix_titles.csv')

data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data = data.iloc[:, [2,3,4,7,10]]

# %%
data.to_csv('data/netflix_titles.csv', index=False)

# %%
data
# Out:
#                                    Title                          Genre  \
# 0                    Beasts of No Nation                     Drama, War
# 1                       The Ridiculous 6      Action, Adventure, Comedy
# 2                  Pee-wee's Big Holiday                 Comedy, Family
# 3                 Special Correspondents                         Comedy
# 4                            The Do-Over      Action, Adventure, Comedy
# ..                                   ...                            ...
# 876                    Take Care of Maya                    Documentary
# 877  Eldorado: Everything the Nazis Hate    Documentary, Drama, History
# 878                                Wham!  Documentary, Biography, Music
# 879               Unknown: Cave of Bones                    Documentary
# 880                   The Deepest Breath  Documentary, Adventure, Sport
#
#                Director                                               Cast
# ...

# %%
data.to_csv('completed_netflix.csv', index=False)

# %%
import pandas as pd

CSV_FILE = "data/data_all_fixed_robust.csv"

# wczytaj plik
df = pd.read_csv(CSV_FILE)

# dodaj dwie nowe kolumny z wartościami domyślnymi 0
df["to_watch"] = 0
df["watched"] = 0

# zapisz z powrotem do tego samego pliku (nadpisanie)
df.to_csv(CSV_FILE, index=False)

print("Dodano kolumny 'to_watch' i 'watched' do pliku CSV.")
# Out:
# Dodano kolumny 'to_watch' i 'watched' do pliku CSV.
